# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('data/kaggle_survey_2020_responses.csv')
data
# Out:
#       Time from Start to Finish (seconds)                           Q1  \
# 0                   Duration (in seconds)  What is your age (# years)?
# 1                                    1838                        35-39
# 2                                  289287                        30-34
# 3                                     860                        35-39
# 4                                     507                        30-34
# ...                                   ...                          ...
# 20032                                 126                        18-21
# 20033                                 566                        55-59
# 20034                                 238                        30-34
# 20035                                 625                        22-24
# 20036                                1031                        22-24
#
#                                            Q2  \
# 0      What is your gender? - Selected Choice
# 1                                         Man
# 2                                         Man
# 3                                         Man
# 4                                         Man
# ...                                       ...
# 20032                                     Man
# 20033                                   Woman
# 20034                                     Man
# 20035                                     Man
# 20036                                     Man
#
#                                                       Q3  \
# 0              In which country do you currently reside?
# 1                                               Colombia
# 2                               United States of America
# 3                                              Argentina
# 4                               United States of America
# ...                                                  ...
# 20032                                             Turkey
# 20033  United Kingdom of Great Britain and Northern I...
# 20034                                             Brazil
# 20035                                              India
# 20036                                           Pakistan
#
#                                                       Q4  \
# 0      What is the highest level of formal education ...
# 1                                        Doctoral degree
# 2                                        Master’s degree
# 3                                      Bachelor’s degree
# 4                                        Master’s degree
# ...                                                  ...
# 20032  Some college/university study without earning ...
# 20033                                    Master’s degree
# 20034                                    Master’s degree
# 20035                                  Bachelor’s degree
# 20036                                    Master’s degree
#
#                                                       Q5  \
# 0      Select the title most similar to your current ...
# 1                                                Student
# 2                                          Data Engineer
# 3                                      Software Engineer
# 4                                         Data Scientist
# ...                                                  ...
# 20032                                                NaN
# 20033                             Currently not employed
# 20034                                 Research Scientist
# 20035                                  Software Engineer
# 20036                          Machine Learning Engineer
#
#                                                       Q6  \
# 0      For how many years have you been writing code ...
# 1                                             5-10 years
# 2                                             5-10 years
# 3                                            10-20 years
# 4                                             5-10 years
# ...                                                  ...
# 20032                                                NaN
# 20033                                          20+ years
# 20034                                          < 1 years
# 20035                                          3-5 years
# 20036                                          < 1 years
#
#                                                Q7_Part_1  \
# 0      What programming languages do you use on a reg...
# 1                                                 Python
# 2                                                 Python
# 3                                                    NaN
# 4                                                 Python
# ...                                                  ...
# 20032                                                NaN
# 20033                                             Python
# 20034                                             Python
# 20035                                             Python
# 20036                                             Python
#
#                                                Q7_Part_2  \
# 0      What programming languages do you use on a reg...
# 1                                                      R
# 2                                                      R
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                                Q7_Part_3  ...  \
# 0      What programming languages do you use on a reg...  ...
# 1                                                    SQL  ...
# 2                                                    SQL  ...
# 3                                                    NaN  ...
# 4                                                    SQL  ...
# ...                                                  ...  ...
# 20032                                                NaN  ...
# 20033                                                NaN  ...
# 20034                                                NaN  ...
# 20035                                                SQL  ...
# 20036                                                NaN  ...
#
#                                             Q35_B_Part_2  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                  Weights & Biases
# 20036                                  Weights & Biases
#
#                                             Q35_B_Part_3  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                             Q35_B_Part_4  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                             Q35_B_Part_5  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                           TensorBoard
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                       TensorBoard
# 20036                                                NaN
#
#                                             Q35_B_Part_6  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                             Q35_B_Part_7  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                             Q35_B_Part_8  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                            Trains
# 20036                                            Trains
#
#                                             Q35_B_Part_9  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                            Q35_B_Part_10  \
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                   None
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                               None
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
#                                              Q35_B_OTHER
# 0      In the next 2 years, do you hope to become mor...
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                                NaN
# 20035                                                NaN
# 20036                                                NaN
#
# [20037 rows x 355 columns]

# %%
edu_columns=['Q4','Q6','Q15']
ds_columns=['Q5','Q20','Q22']
#y=['Q24']

#edit_data=data[edu_columns+ds_columns+y]
edit_data=data[edu_columns+ds_columns]
edit_data
# Out:
#                                                       Q4  \
# 0      What is the highest level of formal education ...
# 1                                        Doctoral degree
# 2                                        Master’s degree
# 3                                      Bachelor’s degree
# 4                                        Master’s degree
# ...                                                  ...
# 20032  Some college/university study without earning ...
# 20033                                    Master’s degree
# 20034                                    Master’s degree
# 20035                                  Bachelor’s degree
# 20036                                    Master’s degree
#
#                                                       Q6  \
# 0      For how many years have you been writing code ...
# 1                                             5-10 years
# 2                                             5-10 years
# 3                                            10-20 years
# 4                                             5-10 years
# ...                                                  ...
# 20032                                                NaN
# 20033                                          20+ years
# 20034                                          < 1 years
# 20035                                          3-5 years
# 20036                                          < 1 years
#
#                                                      Q15  \
# 0      For how many years have you used machine learn...
# 1                                              1-2 years
# 2                                              1-2 years
# 3                  I do not use machine learning methods
# 4                                              3-4 years
# ...                                                  ...
# 20032                                                NaN
# 20033                                          1-2 years
# 20034              I do not use machine learning methods
# 20035                                          1-2 years
# 20036                                       Under 1 year
#
#                                                       Q5  \
# 0      Select the title most similar to your current ...
# 1                                                Student
# 2                                          Data Engineer
# 3                                      Software Engineer
# 4                                         Data Scientist
# ...                                                  ...
# 20032                                                NaN
# 20033                             Currently not employed
# 20034                                 Research Scientist
# 20035                                  Software Engineer
# 20036                          Machine Learning Engineer
#
#                                                      Q20  \
# 0      What is the size of the company where you are ...
# 1                                                    NaN
# 2                               10,000 or more employees
# 3                                   1000-9,999 employees
# 4                                      250-999 employees
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034                                     0-49 employees
# 20035                           10,000 or more employees
# 20036                                     0-49 employees
#
#                                                      Q22
# 0      Does your current employer incorporate machine...
# 1                                                    NaN
# 2      We have well established ML methods (i.e., mod...
# 3                          No (we do not use ML methods)
# 4      We have well established ML methods (i.e., mod...
# ...                                                  ...
# 20032                                                NaN
# 20033                                                NaN
# 20034  We are exploring ML methods (and may one day p...
# 20035  We recently started using ML methods (i.e., mo...
# 20036                                      I do not know
#
# [20037 rows x 6 columns]

# %%
#결측치가 하나라도 있는 row는?
edit_data[edit_data.isnull().any(axis=1)]
# Out:
#                                                       Q4          Q6  \
# 1                                        Doctoral degree  5-10 years
# 5                                        Master’s degree   3-5 years
# 6                                      Bachelor’s degree   < 1 years
# 7                                      Bachelor’s degree   3-5 years
# 8                                        Master’s degree   < 1 years
# ...                                                  ...         ...
# 20028                                    Master’s degree   3-5 years
# 20029                                    Master’s degree   < 1 years
# 20031                                    Master’s degree         NaN
# 20032  Some college/university study without earning ...         NaN
# 20033                                    Master’s degree   20+ years
#
#                                          Q15                      Q5  \
# 1                                  1-2 years                 Student
# 5                                        NaN       Software Engineer
# 6                                        NaN            Data Analyst
# 7                               Under 1 year                 Student
# 8                                  1-2 years                 Student
# ...                                      ...                     ...
# 20028  I do not use machine learning methods                 Student
# 20029  I do not use machine learning methods            Data Analyst
# 20031                                    NaN                     NaN
# 20032                                    NaN                     NaN
# 20033                              1-2 years  Currently not employed
#
#                   Q20  Q22
# 1                 NaN  NaN
# 5                 NaN  NaN
# 6                 NaN  NaN
# 7                 NaN  NaN
# 8                 NaN  NaN
# ...               ...  ...
# 20028             NaN  NaN
# 20029  0-49 employees  NaN
# 20031             NaN  NaN
# 20032             NaN  NaN
# 20033             NaN  NaN
#
# [9502 rows x 6 columns]

# %%
# 결측치 있는 row 삭제
final_data=edit_data.dropna()
final_data
# Out:
#                                                       Q4  \
# 0      What is the highest level of formal education ...
# 2                                        Master’s degree
# 3                                      Bachelor’s degree
# 4                                        Master’s degree
# 9                                        Doctoral degree
# ...                                                  ...
# 20025                             I prefer not to answer
# 20030                                  Bachelor’s degree
# 20034                                    Master’s degree
# 20035                                  Bachelor’s degree
# 20036                                    Master’s degree
#
#                                                       Q6  \
# 0      For how many years have you been writing code ...
# 2                                             5-10 years
# 3                                            10-20 years
# 4                                             5-10 years
# 9                                             5-10 years
# ...                                                  ...
# 20025                                          1-2 years
# 20030                                        10-20 years
# 20034                                          < 1 years
# 20035                                          3-5 years
# 20036                                          < 1 years
#
#                                                      Q15  \
# 0      For how many years have you used machine learn...
# 2                                              1-2 years
# 3                  I do not use machine learning methods
# 4                                              3-4 years
# 9                                              2-3 years
# ...                                                  ...
# 20025                                          1-2 years
# 20030              I do not use machine learning methods
# 20034              I do not use machine learning methods
# 20035                                          1-2 years
# 20036                                       Under 1 year
#
#                                                       Q5  \
# 0      Select the title most similar to your current ...
# 2                                          Data Engineer
# 3                                      Software Engineer
# 4                                         Data Scientist
# 9                                         Data Scientist
# ...                                                  ...
# 20025                          Machine Learning Engineer
# 20030                                              Other
# 20034                                 Research Scientist
# 20035                                  Software Engineer
# 20036                          Machine Learning Engineer
#
#                                                      Q20  \
# 0      What is the size of the company where you are ...
# 2                               10,000 or more employees
# 3                                   1000-9,999 employees
# 4                                      250-999 employees
# 9                                   1000-9,999 employees
# ...                                                  ...
# 20025                                     0-49 employees
# 20030                                  250-999 employees
# 20034                                     0-49 employees
# 20035                           10,000 or more employees
# 20036                                     0-49 employees
#
#                                                      Q22
# 0      Does your current employer incorporate machine...
# 2      We have well established ML methods (i.e., mod...
# 3                          No (we do not use ML methods)
# 4      We have well established ML methods (i.e., mod...
# 9      We have well established ML methods (i.e., mod...
# ...                                                  ...
# 20025                                      I do not know
# 20030                      No (we do not use ML methods)
# 20034  We are exploring ML methods (and may one day p...
# 20035  We recently started using ML methods (i.e., mo...
# 20036                                      I do not know
#
# [10535 rows x 6 columns]

# %%
#Q4
Q4=final_data.Q4[1:]
Q4
# Out:
# 2               Master’s degree
# 3             Bachelor’s degree
# 4               Master’s degree
# 9               Doctoral degree
# 12              Doctoral degree
#                   ...
# 20025    I prefer not to answer
# 20030         Bachelor’s degree
# 20034           Master’s degree
# 20035         Bachelor’s degree
# 20036           Master’s degree
# Name: Q4, Length: 10534, dtype: object

# %%
plt.figure(figsize=(12,12))
plt.title("Histgram of Q4 column")
plt.xticks(rotation='vertical')
plt.hist(Q4)
plt.show()

# %%
plt.figure(figsize=(16,16))
plt.pie(Q4.value_counts(),
       labels=Q4.value_counts().index,
       autopct='%d%%',
       startangle=90,
       textprops={'fontsize':12})
plt.axis('equal')
plt.title('Pie chart for Q4 column', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Pie chart for Q4 column')

# %%
#Q6
Q6=final_data['Q6'][1:]
Q6
# Out:
# 2         5-10 years
# 3        10-20 years
# 4         5-10 years
# 9         5-10 years
# 12         1-2 years
#             ...
# 20025      1-2 years
# 20030    10-20 years
# 20034      < 1 years
# 20035      3-5 years
# 20036      < 1 years
# Name: Q6, Length: 10534, dtype: object

# %%
Q6.value_counts()
# Out:
# 3-5 years      2537
# 1-2 years      1986
# 5-10 years     1954
# 10-20 years    1519
# < 1 years      1352
# 20+ years      1186
# Name: Q6, dtype: int64

# %%
plt.figure(figsize=(12,16))
plt.hist(Q6)
plt.xticks(rotation='vertical')
plt.title("Histogram for Q6 column", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(24,24))
plt.pie(Q6.value_counts(),
        labels=Q6.value_counts().index,
        autopct="%d%%",
         textprops={'fontsize':24})
plt.axis('equal')
plt.title('Pie chart for Q6 column', fontsize=48)
# Out:
# Text(0.5, 1.0, 'Pie chart for Q6 column')

# %%
#Q15
Q15=final_data.Q15[1:]
Q15
# Out:
# 2                                    1-2 years
# 3        I do not use machine learning methods
# 4                                    3-4 years
# 9                                    2-3 years
# 12                                Under 1 year
#                          ...
# 20025                                1-2 years
# 20030    I do not use machine learning methods
# 20034    I do not use machine learning methods
# 20035                                1-2 years
# 20036                             Under 1 year
# Name: Q15, Length: 10534, dtype: object

# %%
Q15.value_counts()
# Out:
# Under 1 year                             3162
# 1-2 years                                2296
# 2-3 years                                1287
# I do not use machine learning methods    1124
# 3-4 years                                 798
# 5-10 years                                762
# 4-5 years                                 706
# 10-20 years                               233
# 20 or more years                          166
# Name: Q15, dtype: int64

# %%
sns.countplot(y='Q15', data=final_data[1:])
# Out:
# <AxesSubplot:xlabel='count', ylabel='Q15'>

# %%
plt.figure(figsize=(24,24))
plt.pie(Q15.value_counts(),
        labels=Q15.value_counts().index,
        autopct="%d%%",
        colors=sns.color_palette('hls',len(Q15.value_counts().index)),
         textprops={'fontsize':24})
plt.axis('equal')
plt.title('Pie chart for Q15 column', fontsize=48)
# Out:
# Text(0.5, 1.0, 'Pie chart for Q15 column')

# %%
#Q5
Q5=final_data.Q5[1:]
Q5
# Out:
# 2                    Data Engineer
# 3                Software Engineer
# 4                   Data Scientist
# 9                   Data Scientist
# 12              Research Scientist
#                    ...
# 20025    Machine Learning Engineer
# 20030                        Other
# 20034           Research Scientist
# 20035            Software Engineer
# 20036    Machine Learning Engineer
# Name: Q5, Length: 10534, dtype: object

# %%
Q5.value_counts()
# Out:
# Data Scientist               2429
# Software Engineer            1678
# Other                        1368
# Data Analyst                 1216
# Research Scientist           1024
# Machine Learning Engineer     946
# Business Analyst              605
# Product/Project Manager       545
# Data Engineer                 372
# Statistician                  241
# DBA/Database Engineer         110
# Name: Q5, dtype: int64

# %%
plt.figure(figsize=(12,12))
#plt.hist(Q5)
plt.barh(Q5.value_counts().index, Q5.value_counts().values)
plt.title("Histogram for Q5 column", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(24,24))
plt.pie(Q5.value_counts(),
        labels=Q5.value_counts().index,
        autopct="%d%%",
        colors=sns.color_palette('hls',len(Q5.value_counts().index)),
         textprops={'fontsize':24})
plt.axis('equal')
plt.title('Pie chart for Q5 column', fontsize=48)
# Out:
# Text(0.5, 1.0, 'Pie chart for Q5 column')

# %%
#Q20
Q20=final_data.Q20[1:]
Q20.value_counts()
# Out:
# 0-49 employees              3823
# 10,000 or more employees    2084
# 1000-9,999 employees        1804
# 50-249 employees            1553
# 250-999 employees           1270
# Name: Q20, dtype: int64

# %%
sns.countplot(data=final_data[1:],y='Q20')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Q20'>

# %%
plt.figure(figsize=(24,24))
plt.pie(Q20.value_counts(),
        labels=Q20.value_counts().index,
        autopct="%d%%",
        colors=sns.color_palette('hls',len(Q20.value_counts().index)),
         textprops={'fontsize':24})
plt.axis('equal')
plt.title('Pie chart for Q20 column', fontsize=48)
# Out:
# Text(0.5, 1.0, 'Pie chart for Q20 column')

# %%
#Q22
Q22=final_data.Q22[1:]
Q22.value_counts()
# Out:
# We are exploring ML methods (and may one day put a model into production)                    2253
# No (we do not use ML methods)                                                                2005
# We have well established ML methods (i.e., models in production for more than 2 years)       1881
# We recently started using ML methods (i.e., models in production for less than 2 years)      1765
# I do not know                                                                                1414
# We use ML methods for generating insights (but do not put working models into production)    1216
# Name: Q22, dtype: int64

# %%
plt.figure(figsize=(12,10))
plt.barh(Q22.value_counts().index, Q22.value_counts().values)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.figure(figsize=(15,15))
plt.pie(Q22.value_counts(),
        labels=Q22.value_counts().index,
        autopct="%d%%",
        colors=sns.color_palette('hls',len(Q22.value_counts().index)),
         textprops={'fontsize':24})
plt.axis('equal')
plt.title('Pie chart for Q22 column', fontsize=48)
# Out:
# Text(0.5, 1.0, 'Pie chart for Q22 column')

# %%
# (Optional)
data.Q3.unique()
# Out:
# array(['In which country do you currently reside?', 'Colombia',
#        'United States of America', 'Argentina', 'Japan', 'India',
#        'Brazil', 'China', 'Germany', 'Indonesia', 'Canada', 'Switzerland',
#        'Other', 'Singapore', 'Russia', 'South Africa', 'Egypt',
#        'Netherlands', 'Pakistan', 'Nepal', 'South Korea', 'Poland',
#        'Belarus', 'Tunisia', 'Ukraine', 'Belgium', 'Saudi Arabia',
#        'Taiwan', 'Nigeria', 'Italy', 'Spain', 'United Arab Emirates',
#        'Mexico', 'Viet Nam', 'Thailand',
#        'United Kingdom of Great Britain and Northern Ireland', 'France',
#        'Ghana', 'Ireland', 'Philippines', 'Morocco', 'Turkey',
#        'Iran, Islamic Republic of...', 'Peru', 'Romania',
#        'Republic of Korea', 'Australia', 'Chile', 'Kenya', 'Sweden',
#        'Bangladesh', 'Greece', 'Malaysia', 'Portugal', 'Israel',
#        'Sri Lanka'], dtype=object)

# %%
skorea=data[data.Q3.isin(['Republic of Korea', 'South Korea'])]
skorea.head()
# Out:
#     Time from Start to Finish (seconds)     Q1   Q2                 Q3  \
# 39                                  592  25-29  Man        South Korea
# 234                                1439  35-39  Man  Republic of Korea
# 286                                 237  40-44  Man        South Korea
# 366                               16200  25-29  Man  Republic of Korea
# 371                                 668  35-39  Man  Republic of Korea
#
#                       Q4                       Q5          Q6 Q7_Part_1  \
# 39       Master’s degree   Currently not employed  5-10 years    Python
# 234  Professional degree             Data Analyst  5-10 years    Python
# 286    Bachelor’s degree   Currently not employed   1-2 years    Python
# 366      Master’s degree                  Student   3-5 years    Python
# 371      Master’s degree  Product/Project Manager   < 1 years    Python
#
#     Q7_Part_2 Q7_Part_3  ... Q35_B_Part_2 Q35_B_Part_3 Q35_B_Part_4  \
# 39          R       NaN  ...          NaN          NaN          NaN
# 234         R       SQL  ...          NaN          NaN          NaN
# 286       NaN       NaN  ...          NaN          NaN          NaN
# 366       NaN       NaN  ...          NaN          NaN          NaN
# 371       NaN       NaN  ...          NaN          NaN          NaN
#
#       Q35_B_Part_5 Q35_B_Part_6 Q35_B_Part_7 Q35_B_Part_8 Q35_B_Part_9  \
# 39    TensorBoard           NaN          NaN          NaN          NaN
# 234            NaN          NaN          NaN          NaN          NaN
# 286            NaN          NaN          NaN          NaN          NaN
# 366            NaN          NaN          NaN          NaN          NaN
# 371            NaN          NaN          NaN          NaN          NaN
#
#     Q35_B_Part_10 Q35_B_OTHER
# 39            NaN         NaN
# 234          None         NaN
# 286           NaN         NaN
# 366           NaN         NaN
# 371          None         NaN
#
# [5 rows x 355 columns]

# %%
sQ4=skorea.Q4
sQ4.value_counts()
# Out:
# Master’s degree                                                      82
# Bachelor’s degree                                                    68
# Doctoral degree                                                      40
# Some college/university study without earning a bachelor’s degree    34
# Professional degree                                                  10
# No formal education past high school                                  8
# I prefer not to answer                                                5
# Name: Q4, dtype: int64

# %%
sns.countplot(data=skorea, y='Q4')
# Out:
# <AxesSubplot:xlabel='count', ylabel='Q4'>

# %%
plt.figure(figsize=(15,15))
plt.pie(sQ4.value_counts(),
        labels=sQ4.value_counts().index,
        autopct="%d%%",
        colors=sns.color_palette('hls',len(sQ4.value_counts().index)),
         textprops={'fontsize':24})
plt.axis('equal')
plt.title('Pie chart for sQ4 column', fontsize=48)
# Out:
# Text(0.5, 1.0, 'Pie chart for sQ4 column')
